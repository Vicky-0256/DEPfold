# %%
import os
import glob
import re
from concurrent.futures import ProcessPoolExecutor, as_completed
from tqdm import tqdm

def process_seq_file(filename):
    with open(filename, 'r') as f:
        lines = f.readlines()
        if len(lines) < 3:
            raise ValueError(f"SEQ file {filename} has insufficient lines")
    
    sequence = re.sub(r'\d', '', lines[-1].strip())  # Remove all digits from the last line
    
    with open(filename, 'w') as f:
        f.writelines(lines[:2])  # Write the first two lines unchanged
        f.write(sequence + '\n')  # Write the modified sequence
    
    return sequence

def correct_ct_file(seq_filename, ct_filename):
    try:
        sequence = process_seq_file(seq_filename)

        with open(ct_filename, 'r') as f:
            ct_lines = f.readlines()

        corrected_lines = [f"{len(sequence)}\t{ct_lines[0].split(maxsplit=2)[2]}"]

        for seq_index, base in enumerate(sequence, start=1):
            if seq_index < len(ct_lines):
                ct_line = ct_lines[seq_index].split()
                if len(ct_line) >= 6:
                    ct_line[0] = str(seq_index)
                    ct_line[1] = base
                    ct_line[2] = str(seq_index - 1)
                    ct_line[3] = str(seq_index + 1 if seq_index < len(sequence) else 0)
                    ct_line[5] = str(seq_index)
                    corrected_lines.append('\t'.join(ct_line) + '\n')
                else:
                    raise ValueError(f"CT file line {seq_index} has insufficient columns")
            else:
                new_line = f"{seq_index}\t{base}\t{seq_index-1}\t{seq_index+1}\t0\t{seq_index}\n"
                corrected_lines.append(new_line)

        with open(ct_filename, 'w') as f:
            f.writelines(corrected_lines)

        return f"Processed: {seq_filename} and {ct_filename}"
    except Exception as e:
        return f"Error processing {seq_filename} and {ct_filename}: {str(e)}"

def process_folder(folder_path):
    seq_files = glob.glob(os.path.join(folder_path, "*.seq"))
    total_files = len(seq_files)

    with ProcessPoolExecutor() as executor:
        futures = []
        for seq_file in seq_files:
            base_name = os.path.splitext(os.path.basename(seq_file))[0]
            ct_files = glob.glob(os.path.join(folder_path, f"{base_name}*.ct"))
            
            if not ct_files:
                print(f"No CT file found for {seq_file}")
            else:
                for ct_file in ct_files:
                    futures.append(executor.submit(correct_ct_file, seq_file, ct_file))
        
        for future in tqdm(as_completed(futures), total=len(futures), desc="Processing files"):
            print(future.result())

if __name__ == "__main__":
    folder_path = "/home/ke/Documents/RNA_parser/RNA_parser/data/RNAstrAlign/train/ct_seq"
    process_folder(folder_path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [1], line 74
#      72 if __name__ == "__main__":
#      73     folder_path = "/home/ke/Documents/RNA_parser/RNA_parser/data/RNAstrAlign/train/ct_seq"
# ---> 74     process_folder(folder_path)
#
# Cell In [1], line 61, in process_folder(folder_path)
#      59 for seq_file in seq_files:
#      60     base_name = os.path.splitext(os.path.basename(seq_file))[0]
# ---> 61     ct_files = glob.glob(os.path.join(folder_path, f"{base_name}*.ct"))
#      63     if not ct_files:
#      64         print(f"No CT file found for {seq_file}")
#
# File ~/anaconda3/envs/mlp/lib/python3.10/glob.py:24, in glob(pathname, root_dir, dir_fd, recursive)
#      13 def glob(pathname, *, root_dir=None, dir_fd=None, recursive=False):
#      14     """Return a list of paths matching a pathname pattern.
#      15
#      16     The pattern may contain simple shell-style wildcards a la
#    (...)
#      22     zero or more directories and subdirectories.
#      23     """
# ---> 24     return list(iglob(pathname, root_dir=root_dir, dir_fd=dir_fd, recursive=recursive))
#
# File ~/anaconda3/envs/mlp/lib/python3.10/glob.py:86, in _iglob(pathname, root_dir, dir_fd, recursive, dironly)
#      84     glob_in_dir = _glob0
#      85 for dirname in dirs:
# ---> 86     for name in glob_in_dir(_join(root_dir, dirname), basename, dir_fd, dironly):
#      87         yield os.path.join(dirname, name)
#
# File ~/anaconda3/envs/mlp/lib/python3.10/glob.py:94, in _glob1(dirname, pattern, dir_fd, dironly)
#      93 def _glob1(dirname, pattern, dir_fd, dironly):
# ---> 94     names = _listdir(dirname, dir_fd, dironly)
#      95     if not _ishidden(pattern):
#      96         names = (x for x in names if not _ishidden(x))
#
# File ~/anaconda3/envs/mlp/lib/python3.10/glob.py:164, in _listdir(dirname, dir_fd, dironly)
#     162 def _listdir(dirname, dir_fd, dironly):
#     163     with contextlib.closing(_iterdir(dirname, dir_fd, dironly)) as it:
# --> 164         return list(it)
#
# File ~/anaconda3/envs/mlp/lib/python3.10/glob.py:149, in _iterdir(dirname, dir_fd, dironly)
#     147 for entry in it:
#     148     try:
# --> 149         if not dironly or entry.is_dir():
#     150             if fsencode is not None:
#     151                 yield fsencode(entry.name)
#
# KeyboardInterrupt:
